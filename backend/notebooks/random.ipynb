# %%
primes = []
for num in range(2,201):
    prime = True
    for i in range(2,num):
        if (num%i==0):
            prime = False
    if prime:
       primes.append(num)

# %%
raised_two = []
for p in primes:
    raised_two.append(2**p)

# %%
raised_two

# %%
import math
for i in range(1, len(raised_two)):
    # this makes sense, division is simply subtraction in our world
    # i dont know why i did this
    # ln of some number is the average gap in our world
    # same for their world too? what are those values in our world?
    # in mult, number of exponentiations is the count
    # im running around in circles
    # gotta love how division is literally subtraction in that world though
    print(math.log(raised_two[i] / raised_two[i-1], 2))

# %% [markdown]
# Behavior of prime numbers in the multiplication world.
# They would be the same as our numbers, but "raised to".
#
# the average gap of times is `ln(N)`.
#
#
# The operation `ln` brings down the number from mult space to add space. its like a change of basis.
# the numbers which cant be created by multiplying two numbers are primes. they are the basis of multiplication in our space.
# These are "primes".
#
# In the multiplication world, numbers which cant be created by exponentiating `2` with a combination of numbers are prime.
# These are repeated every `ln(N)` times. what does `ln` mean in the multiplication world?
#
# in our world, ln means the number times we are multiplying. in multiplication world, it means the number of times we are exponentiating. in the lower world, it means how many times we are adding the identity of that world to bring it to that world.
#
#
# what is interesting is that its the counting of the operations needed to make us.
# Its the bridge. to the lower world.
#
#
# Now im assuming that if i know how the "numbers" in the lower world look, i might be able to make some sort of assumptions about primes.
# im saying, if i use that to represent my world primes, ill get some connection.
#
#
# which is what i can do by checking in the multiplicative world. if im able to model the primes in that world using our world, maube it works.
#
#
#
# # average gap in mult world
#
# in the mult world, the average gap is LNM(N) (LNM is ln of multiplicative world). When i take ln of it, i see it in my world. its simply 2^prime gap in our world.
#
#
# LNM(N of mult world) is the average number of primes around N, the next prime would be approximately LNM(N) values later.
#
# LNM is the count of exponentiation.

# %%
import matplotlib.pyplot as plt

# %%
# primes come every log number of times
