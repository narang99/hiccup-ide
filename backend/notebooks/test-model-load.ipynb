# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random
import torch
from hiccup_ide.mnist import SimpleMNIST
from hiccup_ide.model_to_json import model_to_json

# %%
PUBLIC_FOLDER = Path("/Users/hariomnarang/Desktop/personal/hiccup-ide/frontend/neural-viz/public")

# %%
# with open
import json
# print(json.dumps(, indent=2))

o = model_to_json(SimpleMNIST(), (1, 1, 28, 28))
# with open(PUBLIC_FOLDER / "example-model.json", "w") as f:
#     json.dump(o, f, indent=2)

# %%
from hiccup_ide.persist.activation_processor_outputs import dump_coordinates_to_files
from hiccup_ide.persist.contribs_processor_outputs import dump_contribs_to_files
from hiccup_ide.mnist import SimpleMNIST, get_contribs_for_inp_vectorized
from hiccup_ide.capture import get_model_internals
from hiccup_ide.activation_processor import process_activations_to_coordinates


model = SimpleMNIST()
model.load_state_dict(torch.load("../data/model.pt"))
inp = torch.load("../data/first-input-tens.pt", weights_only=False).to("cpu")

# %%
model.to("cpu")
activations, parameters = get_model_internals(model, inp)
activations.keys()
# Out:
# dict_keys(['layers.0', 'layers.0.out_0.in_0', 'layers.0.out_0.in_0.input', 'layers.0.out_1.in_0', 'layers.0.out_1.in_0.input', 'layers.0.out_2.in_0', 'layers.0.out_2.in_0.input', 'layers.0.out_3.in_0', 'layers.0.out_3.in_0.input', 'layers.0.out_4.in_0', 'layers.0.out_4.in_0.input', 'layers.0.out_5.in_0', 'layers.0.out_5.in_0.input', 'layers.0.out_6.in_0', 'layers.0.out_6.in_0.input', 'layers.0.out_7.in_0', 'layers.0.out_7.in_0.input', 'layers.1', 'layers.2', 'layers.2.out_0.in_0', 'layers.2.out_0.in_0.input', 'layers.2.out_0.in_1', 'layers.2.out_0.in_1.input', 'layers.2.out_0.in_2', 'layers.2.out_0.in_2.input', 'layers.2.out_0.in_3', 'layers.2.out_0.in_3.input', 'layers.2.out_0.in_4', 'layers.2.out_0.in_4.input', 'layers.2.out_0.in_5', 'layers.2.out_0.in_5.input', 'layers.2.out_0.in_6', 'layers.2.out_0.in_6.input', 'layers.2.out_0.in_7', 'layers.2.out_0.in_7.input', 'layers.2.out_1.in_0', 'layers.2.out_1.in_0.input', 'layers.2.out_1.in_1', 'layers.2.out_1.in_1.input', 'layers.2.out_1
# ...

# %%
# dump done
coordinate_data = process_activations_to_coordinates(activations, parameters, model)
# dump_coordinates_to_files(coordinate_data, PUBLIC_FOLDER / "activations")
[k for k in coordinate_data.keys() if k.startswith("layers.2.out_0")]
# Out:
# ['layers.2.out_0',
#  'layers.2.out_0.in_0',
#  'layers.2.out_0.in_0.input',
#  'layers.2.out_0.in_1',
#  'layers.2.out_0.in_1.input',
#  'layers.2.out_0.in_2',
#  'layers.2.out_0.in_2.input',
#  'layers.2.out_0.in_3',
#  'layers.2.out_0.in_3.input',
#  'layers.2.out_0.in_4',
#  'layers.2.out_0.in_4.input',
#  'layers.2.out_0.in_5',
#  'layers.2.out_0.in_5.input',
#  'layers.2.out_0.in_6',
#  'layers.2.out_0.in_6.input',
#  'layers.2.out_0.in_7',
#  'layers.2.out_0.in_7.input']

# %%
inp.shape
# Out:
# torch.Size([1, 1, 28, 28])

# %%
from hiccup_ide.contrib_processor import process_contribs_to_coordinates
from hiccup_ide.utils import get_ratios_for_labels
contribs, _, _ = get_contribs_for_inp_vectorized(inp, model, get_ratios_for_labels([9]), "cpu")
contrib_coordinates = process_contribs_to_coordinates(contribs, 0)
dump_contribs_to_files(contrib_coordinates, PUBLIC_FOLDER / "saliency_map")
